# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()

# %%
data = pd.read_csv(r"D:\IT\Data Science\Python\Affitech Technologies\Python and Machine Learning Notes\Project Assignments\CardiovascularDiseaseDetection\cardio_train.csv")

# %%
data
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0        988  22469       1     155    69.0    130     80            2     2
# 1        989  14648       1     163    71.0    110     70            1     1
# 2        990  21901       1     165    70.0    120     80            1     1
# 3        991  14549       2     165    85.0    120     80            1     1
# 4        992  23393       1     155    62.0    120     80            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69296  99993  19240       2     168    76.0    120     80            1     1
# 69297  99995  22601       1     158   126.0    140     90            2     2
# 69298  99996  19066       2     183   105.0    180     90            3     1
# 69299  99998  22431       1     163    72.0    135     80            1     2
# 69300  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
#Convert age (Days to Years)
data['age'] = data['age']/365

# %%
data['age']
# Out:
# 0        61.558904
# 1        40.131507
# 2        60.002740
# 3        39.860274
# 4        64.090411
#            ...
# 69296    52.712329
# 69297    61.920548
# 69298    52.235616
# 69299    61.454795
# 69300    56.273973
# Name: age, Length: 69301, dtype: float64

# %%
data
# Out:
#           id        age  gender  height  weight  ap_hi  ap_lo  cholesterol  \
# 0        988  61.558904       1     155    69.0    130     80            2
# 1        989  40.131507       1     163    71.0    110     70            1
# 2        990  60.002740       1     165    70.0    120     80            1
# 3        991  39.860274       2     165    85.0    120     80            1
# 4        992  64.090411       1     155    62.0    120     80            1
# ...      ...        ...     ...     ...     ...    ...    ...          ...
# 69296  99993  52.712329       2     168    76.0    120     80            1
# 69297  99995  61.920548       1     158   126.0    140     90            2
# 69298  99996  52.235616       2     183   105.0    180     90            3
# 69299  99998  61.454795       1     163    72.0    135     80            1
# 69300  99999  56.273973       1     170    72.0    120     80            2
#
#        gluc  smoke  alco  active  cardio
# ...

# %%
# Checking the null value by vizualization 
plt.figure(figsize = (15,10))
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
#CHecking null value
data.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
data.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  69301.000000  69301.000000  69301.000000  69301.000000  69301.000000
# mean   50471.480397     53.339140      1.349519    164.362217     74.203027
# std    28563.100347      6.759621      0.476821      8.205337     14.383469
# min      988.000000     29.583562      1.000000     55.000000     10.000000
# 25%    25745.000000     48.394521      1.000000    159.000000     65.000000
# 50%    50494.000000     53.983562      1.000000    165.000000     72.000000
# 75%    75150.000000     58.427397      2.000000    170.000000     82.000000
# max    99999.000000     64.967123      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  69301.000000  69301.000000  69301.000000  69301.000000  69301.000000
# mean     128.829584     96.650092      1.366806      1.226447      0.088051
# ...

# %%
data.size
# Out:
# 900913

# %%
df = data.drop(columns = ['id'])
df.head()
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  61.558904       1     155    69.0    130     80            2     2      0
# 1  40.131507       1     163    71.0    110     70            1     1      0
# 2  60.002740       1     165    70.0    120     80            1     1      0
# 3  39.860274       2     165    85.0    120     80            1     1      1
# 4  64.090411       1     155    62.0    120     80            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       1       0
# 3     1       1       0
# 4     0       1       0

# %%
# Data Distribution for every column 
plt.figure(figsize = (20,25), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <= 12:      # there are 12 columns in the data
        ax = plt.subplot(4,3, plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column, fontsize = 20)
    plotnumber+=1
plt.show()
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Asus\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
fig,ax = plt.subplots(figsize = (15,10))
sns.boxplot(data = df, width = 0.5, ax = ax, fliersize = 3)
# Out:
# <AxesSubplot:>

# %%
q = df['ap_hi'].quantile(0.90)
#removing 3% data from 'ap_hi' column
data_cleaned = df[df['ap_hi'] < q]

q = df['ap_lo'].quantile(0.94)
#removing 3% data from 'ap_hi' column
data_cleaned = df[df['ap_lo'] < q]

# %%
# Data Distribution for every column after removing outliers
plt.figure(figsize = (20,25), facecolor = 'white')
plotnumber = 1

for column in data_cleaned:
    if plotnumber <= 12:      # there are 12 columns in the data
        ax = plt.subplot(4,3, plotnumber)
        sns.distplot(data_cleaned[column])
        plt.xlabel(column, fontsize = 20)
    plotnumber+=1
plt.show()
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Asus\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
fig,ax = plt.subplots(figsize = (20,15))
sns.boxplot(data = data_cleaned, width = 0.5, ax = ax, fliersize = 4)
# Out:
# <AxesSubplot:>

# %%
X = df.drop(columns = ['cardio'], axis = 1)
y = df['cardio']

# %%
y = pd.DataFrame(y)
y
# Out:
#        cardio
# 0           0
# 1           1
# 2           0
# 3           0
# 4           0
# ...       ...
# 69296       0
# 69297       1
# 69298       1
# 69299       1
# 69300       0
#
# [69301 rows x 1 columns]

# %%
#importing necessary librearies for machine learning
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score, f1_score

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[ 1.21601824, -0.73302344, -1.14099939, ..., -0.31072844,
#         -0.23864069,  0.49376463],
#        [-1.95391548, -0.73302344, -0.16601717, ..., -0.31072844,
#         -0.23864069,  0.49376463],
#        [ 0.98580185, -0.73302344,  0.07772839, ..., -0.31072844,
#         -0.23864069,  0.49376463],
#        ...,
#        [-0.16325352,  1.36421285,  2.27143838, ..., -0.31072844,
#          4.19040018, -2.02525646],
#        [ 1.20061644, -0.73302344, -0.16601717, ..., -0.31072844,
#         -0.23864069, -2.02525646],
#        [ 0.43417421, -0.73302344,  0.68709227, ..., -0.31072844,
#         -0.23864069,  0.49376463]])

# %%
x_train, x_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.25, random_state = 350)

# %%
#Implementing LogisticRegression

log_reg = LogisticRegression()

log_reg.fit(x_train, y_train)
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# LogisticRegression()

# %%
y_pred = log_reg.predict(x_test)

# %%
#accuracy score
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.7156296894840125

# %%
conf_mat = confusion_matrix(y_test, y_pred)
conf_mat
# Out:
# array([[6568, 2112],
#        [2815, 5831]], dtype=int64)

# %%
# F1 score
score = f1_score(y_test, y_pred)
score
# Out:
# 0.7029959611790946

# %%
#Area under curve
auc = roc_auc_score(y_test, y_pred)
auc
# Out:
# 0.7155489712618499

# %%
#Implementing Support Vector Machine

from sklearn.svm import SVC

# %%
clf = SVC()
clf.fit(x_train, y_train)
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# SVC()

# %%
y_pred = clf.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.727923352187464

# %%
#Implementing Decision Tree

from sklearn.tree import DecisionTreeClassifier

# %%
dt_clf = DecisionTreeClassifier()
dt_clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_clf.score(x_test, y_test)
# Out:
# 0.6304975181807688

# %%
y_pred = dt_clf.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred) 
accuracy
# Out:
# 0.6304975181807688

# %%
#Implementing KNN

from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
knn.score(x_test, y_test)
# Out:
# <ipython-input-38-41153aa8eeb2>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   knn.fit(x_train, y_train)
# 0.6506983723883182

# %%
#Implementing Random Forest

from sklearn.ensemble import RandomForestClassifier

# %%
rand_clf = RandomForestClassifier()

rand_clf.fit(x_train, y_train)
rand_clf.score(x_test, y_test)
# Out:
# <ipython-input-50-c81fb94ba2e7>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rand_clf.fit(x_train, y_train)
# 0.7158028396629343

# %%
grid_param = {
    "n_estimators" : [90, 100, 115],
    'criterion' : ['gini', 'entropy'],
    'min_samples_leaf' : [1,2,3,4,5],
    'min_samples_split' : [4,5,6,7,8],
    'max_features' : ['auto', 'log2']
}

# %%
grid_search = GridSearchCV(estimator = rand_clf, param_grid = grid_param, cv = 5, n_jobs = -1)

# %%
grid_search.fit(x_test, y_test)
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:765: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_features': ['auto', 'log2'],
#                          'min_samples_leaf': [1, 2, 3, 4, 5],
#                          'min_samples_split': [4, 5, 6, 7, 8],
#                          'n_estimators': [90, 100, 115]})

# %%
grid_search.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_features': 'auto',
#  'min_samples_leaf': 5,
#  'min_samples_split': 4,
#  'n_estimators': 115}

# %%
rand_clf = RandomForestClassifier(criterion = 'entropy', max_features = 'auto', min_samples_leaf = 5, min_samples_split = 4, n_estimators = 115)

# %%
rand_clf.fit(x_test, y_test)
# Out:
# <ipython-input-57-1009be182f28>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rand_clf.fit(x_test, y_test)
# RandomForestClassifier(criterion='entropy', min_samples_leaf=5,
#                        min_samples_split=4, n_estimators=115)

# %%
rand_clf.score(x_test, y_test)
# Out:
# 0.8117857555119473

# %% [markdown]
# # Now We can use this Random forest model algorithm for cloud deployment
